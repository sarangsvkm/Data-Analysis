# %%
import pandas as pd
sales=pd.read_csv('sales.csv')

# %%
sales
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 609   437241799  3/10/2018  19:02    Male  Water tower  Chicago     No
# 610   486005290  2/25/2018  18:22  Female   Brookfield  NewYork    Yes
# 611   524232746  1/29/2018  20:33  Female   Brookfield  NewYork     No
# 612   357755511  3/12/2018  15:01  Female    Park lane   Dallas     No
# 613   445899503  1/24/2018  18:27  Female    Park lane   Dallas    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash     2.0
# ...

# %%
sales.head(10)
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5   263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# 6    99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7   188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# 8   325637547  1/18/2018  15:33    Male    Park lane   Dallas    Yes
# 9   562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating
# 0  Groceries     30         1     30    Cash     2.0
# 1    Fashion     35         5    175    Card     3.0
# ...

# %%
sales['Location']
# Out:
# 0       Brookfield
# 1      Water tower
# 2      Water tower
# 3        Park lane
# 4        Park lane
#           ...
# 609    Water tower
# 610     Brookfield
# 611     Brookfield
# 612      Park lane
# 613      Park lane
# Name: Location, Length: 614, dtype: object

# %%
sales['Category']
# Out:
# 0      Groceries
# 1        Fashion
# 2       Clothing
# 3       Sporting
# 4          Books
#          ...
# 609    Groceries
# 610    Groceries
# 611      Fashion
# 612     Sporting
# 613    Groceries
# Name: Category, Length: 614, dtype: object

# %%
sales['Category'].unique()
# Out:
# array(['Groceries', 'Fashion', 'Clothing', 'Sporting', 'Books',
#        'Furniture'], dtype=object)

# %%
sales.iloc[200]
# Out:
# Invoice ID      576523018
# Date            2/15/2018
# Time                12:35
# Gender               Male
# Location      Water tower
# City              Chicago
# Member                 No
# Category        Groceries
# Price                  82
# Quantity                1
# Total                  82
# Payment              Card
# Rating                4.0
# Name: 200, dtype: object

# %%
sales[200:210]
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 200   576523018  2/15/2018  12:35    Male  Water tower  Chicago     No
# 201   414119922  1/30/2018  11:07    Male  Water tower  Chicago     No
# 202   123247697   2/8/2018  20:03    Male   Brookfield  NewYork     No
# 203    40419058  1/26/2018  14:53    Male  Water tower  Chicago    Yes
# 204   890497298  2/25/2018  18:06  Female  Water tower  Chicago     No
# 205   885702268  1/28/2018  12:45    Male   Brookfield  NewYork     No
# 206   172252194  3/22/2018  20:10  Female    Park lane   Dallas     No
# 207   866140211  2/25/2018  13:34  Female    Park lane   Dallas     No
# 208   597678548  3/15/2018  17:35    Male  Water tower  Chicago    Yes
# 209   428818456  2/25/2018  18:50    Male    Park lane   Dallas    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 200  Groceries     82         1     82    Card     4.0
# 201   Sporting     44         7    308    Card     3.0
# ...

# %%
sales[sales['Gender']=='Male']
# Out:
#      Invoice ID       Date   Time Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46   Male   Brookfield  NewYork    Yes
# 2     411909258  2/25/2018  13:33   Male  Water tower  Chicago     No
# 5     263634050   3/9/2018  17:55   Male   Brookfield  NewYork    Yes
# 6      99646662   3/4/2018  13:21   Male  Water tower  Chicago     No
# 7     188869875   3/8/2018  13:24   Male    Park lane   Dallas     No
# ..          ...        ...    ...    ...          ...      ...    ...
# 598   262731416  2/15/2018  14:06   Male    Park lane   Dallas     No
# 602   144597774  3/11/2018  11:55   Male   Brookfield  NewYork    Yes
# 605   113236778  2/12/2018  13:30   Male   Brookfield  NewYork    Yes
# 607   326311886  1/23/2018  11:26   Male  Water tower  Chicago     No
# 609   437241799  3/10/2018  19:02   Male  Water tower  Chicago     No
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash     2.0
# ...

# %%
sales[sales['Gender']=='Female'].head(10)
# Out:
#     Invoice ID       Date   Time  Gender     Location     City Member  \
# 1    471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 3    487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4    197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 9    562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
# 10   388412668  2/26/2018  11:32  Female   Brookfield  NewYork     No
# 13   942406749  1/18/2018  15:20  Female  Water tower  Chicago    Yes
# 14   547572603  3/21/2018  13:23  Female   Brookfield  NewYork     No
# 15   355981315  2/15/2018  15:47  Female   Brookfield  NewYork    Yes
# 16   397754805   2/9/2018  15:59  Female   Brookfield  NewYork    Yes
# 18   542144906   2/6/2018  10:58  Female   Brookfield  NewYork    Yes
#
#      Category  Price  Quantity  Total Payment  Rating
# 1     Fashion     35         5    175    Card     3.0
# 3    Sporting     89         4    356    Gpay     1.0
# ...

# %%
sales[sales['Total']>100]
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5     263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# ..          ...        ...    ...     ...          ...      ...    ...
# 608   988159876   1/8/2018  14:16  Female   Brookfield  NewYork    Yes
# 609   437241799  3/10/2018  19:02    Male  Water tower  Chicago     No
# 611   524232746  1/29/2018  20:33  Female   Brookfield  NewYork     No
# 612   357755511  3/12/2018  15:01  Female    Park lane   Dallas     No
# 613   445899503  1/24/2018  18:27  Female    Park lane   Dallas    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 1      Fashion     35         5    175    Card     3.0
# ...

# %%
sales["Payment"].unique()
# Out:
# array(['Cash', 'Card', 'Gpay', 'Ca'], dtype=object)

# %%
sales[sales["Payment"]=='Cash']
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 6      99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7     188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 594   415609214  2/20/2018  10:37  Female   Brookfield  NewYork     No
# 596   739222343  3/22/2018  14:29  Female    Park lane   Dallas    Yes
# 602   144597774  3/11/2018  11:55    Male   Brookfield  NewYork    Yes
# 611   524232746  1/29/2018  20:33  Female   Brookfield  NewYork     No
# 612   357755511  3/12/2018  15:01  Female    Park lane   Dallas     No
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash     2.0
# ...

# %%
sales["Category"].unique()
# Out:
# array(['Groceries', 'Fashion', 'Clothing', 'Sporting', 'Books',
#        'Furniture'], dtype=object)

# %%
#sales[sales['Total'][100:200]]

# %%
sales.sum()['Total']
# Out:
# 129032

# %%
sales.sum()['Quantity']
# Out:
# 2520

# %%
sales.max()
# Out:
# Invoice ID      999023942
# Date             3/9/2018
# Time                20:59
# Gender               Male
# Location      Water tower
# City              NewYork
# Member                Yes
# Category         Sporting
# Price                 100
# Quantity                7
# Total                 693
# Payment              Gpay
# Rating                5.0
# dtype: object

# %%
sales.max()['Total']
# Out:
# 693

# %%
sales[sales['Total']==sales.max()['Total']]
# Out:
#     Invoice ID       Date   Time  Gender     Location     City Member  \
# 47   315624039  3/30/2018  19:45  Female  Water tower  Chicago    Yes
#
#      Category  Price  Quantity  Total Payment  Rating
# 47  Groceries     99         7    693    Gpay     3.0

# %%
sales['Total'].min()
# Out:
# 1

# %%
sales.mean()['Total']
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_22020\1945902060.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   sales.mean()['Total']
# 210.14983713355048

# %%
sales.head(10)
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5   263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# 6    99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7   188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# 8   325637547  1/18/2018  15:33    Male    Park lane   Dallas    Yes
# 9   562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating
# 0  Groceries     30         1     30    Cash     2.0
# 1    Fashion     35         5    175    Card     3.0
# ...

# %%
sales.groupby('City')

# %%
sales.groupby('City').sum()
# Out:
#            Invoice ID  Price  Quantity  Total  Rating
# City
# Chicago  100008375400   9775       828  41523   626.0
# Dallas    99744739094  10730       834  43805   641.0
# NewYork   98912049005  10721       858  43704   595.0

# %%
sales.groupby('City').sum()['Total']
# Out:
# City
# Chicago    41523
# Dallas     43805
# NewYork    43704
# Name: Total, dtype: int64

# %%
sales.groupby('Date').sum()
# Out:
#            Invoice ID  Price  Quantity  Total  Rating
# Date
# 1/1/2018   4293993980    573        32   2161    31.0
# 1/10/2018  3613517491    241        19    721    19.0
# 1/11/2018  2802391327    252        21   1089    12.0
# 1/12/2018  5941551934    532        40   2341    34.0
# 1/13/2018  4456996929    260        34   1380    14.0
# ...               ...    ...       ...    ...     ...
# 3/5/2018   2995894568    486        39   2619    22.0
# 3/6/2018   3426089525    247        36   1281    21.0
# 3/7/2018   3743477721    151        23    756    14.0
# 3/8/2018   2478328181    350        22   1242    17.0
# 3/9/2018   4130063365    648        48   3270    31.0
#
# [89 rows x 5 columns]

# %%
sales.groupby('Date').sum()['Total']
# Out:
# Date
# 1/1/2018     2161
# 1/10/2018     721
# 1/11/2018    1089
# 1/12/2018    2341
# 1/13/2018    1380
#              ...
# 3/5/2018     2619
# 3/6/2018     1281
# 3/7/2018      756
# 3/8/2018     1242
# 3/9/2018     3270
# Name: Total, Length: 89, dtype: int64

# %%
sales.groupby('Category').sum()['Total']
# Out:
# Category
# Books        22427
# Clothing     23513
# Fashion      18371
# Furniture    22277
# Groceries    19516
# Sporting     22928
# Name: Total, dtype: int64

# %%
sales
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 609   437241799  3/10/2018  19:02    Male  Water tower  Chicago     No
# 610   486005290  2/25/2018  18:22  Female   Brookfield  NewYork    Yes
# 611   524232746  1/29/2018  20:33  Female   Brookfield  NewYork     No
# 612   357755511  3/12/2018  15:01  Female    Park lane   Dallas     No
# 613   445899503  1/24/2018  18:27  Female    Park lane   Dallas    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash     2.0
# ...

# %%
location_list=sales.groupby('Location')

# %%
location=[x for x,y in location_list]
location
# Out:
# ['Brookfield', 'Park lane', 'Water tower']

# %%
sales.groupby('Location').sum()['Total']
# Out:
# Location
# Brookfield     43704
# Park lane      43805
# Water tower    41523
# Name: Total, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(location,sales.groupby('Location').sum()['Total'])
# Out:
# <BarContainer object of 3 artists>

# %%
plt.pie(sales.groupby('Location').sum()['Total'],labels=location)
# Out:
# ([<matplotlib.patches.Wedge at 0x291e52d5340>,
# ...
#  [Text(0.5338412391311188, 0.9617762376992642, 'Brookfield'),
#   Text(-1.0984494835435243, -0.058384348099165394, 'Park lane'),
#   Text(0.5841366473392288, -0.9320860353182455, 'Water tower')])

# %%
#which location has more feamale customers and which location has more male

# %%
sales.groupby('Location')

# %%
sales.groupby(['Location','Gender'])

# %%
location_sales=sales.groupby(['Location','Gender']).count()['Invoice ID']

# %%
location_sales
# Out:
# Location     Gender
# Brookfield   Female    111
#              Male       96
# Park lane    Female    114
#              Male       93
# Water tower  Female     86
#              Male      114
# Name: Invoice ID, dtype: int64

# %%
location_sales.unstack(level=0)
# Out:
# Location  Brookfield  Park lane  Water tower
# Gender
# Female           111        114           86
# Male              96         93          114

# %%
unstacked_sales=location_sales.unstack(level=0)

# %%
unstacked_sales.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Gender'>

# %%
sales.groupby(['Gender','Location'])

# %%
gender_sales=sales.groupby(['Gender','Location']).count()['Invoice ID']

# %%
gender_sales
# Out:
# Gender  Location
# Female  Brookfield     111
#         Park lane      114
#         Water tower     86
# Male    Brookfield      96
#         Park lane       93
#         Water tower    114
# Name: Invoice ID, dtype: int64

# %%
gender_unstacked=gender_sales.unstack(level=0)

# %%
gender_unstacked.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Location'>

# %%
# what days of the month make most sales?

# %%
sales["Date"]
# Out:
# 0      1/25/2018
# 1      3/19/2018
# 2      2/25/2018
# 3      1/22/2018
# 4      2/18/2018
#          ...
# 609    3/10/2018
# 610    2/25/2018
# 611    1/29/2018
# 612    3/12/2018
# 613    1/24/2018
# Name: Date, Length: 614, dtype: object

# %%
pd.to_datetime(sales["Date"]).dt.month
# Out:
# 0      1
# 1      3
# 2      2
# 3      1
# 4      2
#       ..
# 609    3
# 610    2
# 611    1
# 612    3
# 613    1
# Name: Date, Length: 614, dtype: int64

# %%
pd.to_datetime(sales["Date"]).dt.year
# Out:
# 0      2018
# 1      2018
# 2      2018
# 3      2018
# 4      2018
#        ...
# 609    2018
# 610    2018
# 611    2018
# 612    2018
# 613    2018
# Name: Date, Length: 614, dtype: int64

# %%
sales.head(10)
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5   263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# 6    99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7   188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# 8   325637547  1/18/2018  15:33    Male    Park lane   Dallas    Yes
# 9   562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating
# 0  Groceries     30         1     30    Cash     2.0
# 1    Fashion     35         5    175    Card     3.0
# ...

# %%
pd.to_datetime(sales["Date"]).dt.day
# Out:
# 0      25
# 1      19
# 2      25
# 3      22
# 4      18
#        ..
# 609    10
# 610    25
# 611    29
# 612    12
# 613    24
# Name: Date, Length: 614, dtype: int64

# %%
day_sales=sales.groupby('Day').sum()['Total']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22020\2833411917.py in <module>
# ----> 1 day_sales=sales.groupby('Day').sum()['Total']
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7719         # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7720         # "Union[bool, NoDefault]"; expected "bool"
# -> 7721         return DataFrameGroupBy(
#    7722             obj=self,
#    7723             keys=by,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     880             from pandas.core.groupby.grouper import get_grouper
#     881
# ...

# %%
day_sales.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22020\717333594.py in <module>
# ----> 1 day_sales.plot()
#
# NameError: name 'day_sales' is not defined

# %%
#which branch has more mebers vs which has less members?
#whic branch has highest rating and which has the lowest?

# %%
members=sales.groupby(['Member','Location']).count()['Invoice ID']

# %%
members
# Out:
# Member  Location
# No      Brookfield     110
#         Park lane      107
#         Water tower    101
# Yes     Brookfield      97
#         Park lane      100
#         Water tower     99
# Name: Invoice ID, dtype: int64

# %%
members.unstack(level=0).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Location'>

# %%
rateing=sales.groupby(['Location']).mean()['Rating']

# %%
rateing.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Location'>

# %%
#which city has more female shopping
#which spends more man or female?
# which type of customer spands more member or non member
#which product line sells more?
#which product line is popular among men vs woman?

# %%
female_shoppers=sales.groupby(['Gender','City']).count()['Invoice ID']

# %%
female_shoppers.unstack(level=0).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='City'>

# %%
spend=sales.groupby('Gender').sum()['Total']

# %%
spend.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Gender'>
